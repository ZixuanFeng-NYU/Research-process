# %% [markdown]
# # Chemical Genomics of Tuberculosis - 47,272 compounds x 153 strains
#
# 2019-05-15
#
# ## Description
#
# Structure and function annotation of compounds (47,223 unique structures) used in screen.
#
# ## Data structure
#
# One row per compound structure.
#
# ## Columns
#
# **compound_stem**: Compound structure identifier.  Matches longest field of BRD-XXXXXXXXX-XXX-XX-X compound identifiers.
#
# **SMILES**: SMILES string for compound structure.
#
# **compound_name**: Name of compound.
#
# **pubchem_cid**: PubChem Compound ID.
#
# **kegg_id**: KEGGDrug ID.
#
# ## Questions?
#
# Email hung {at} broadinstitute.org.

# %%
import pandas as pd
raw_data_2019_compound_annotation = pd.read_csv('/Users/zixuanfeng/Desktop/NYU/Research/Data collection/2019-05-15_compound-annotation/2019-05-15_compound-annotation.csv')
raw_data_2019_compound_annotation
# Out:
#       compound_stem                                             SMILES  \
# 0         A00052363   CN(C)C(=O)CC1CC2(CCN(CC2)C(=O)N2CCCC2)Oc2ccccc12
# 1         A00055639     Cc1c([nH]c2CC(CC(=O)c12)c1ccco1)C(=O)OCC1CCCO1
# 2         A00064324              CNC(=O)CN1CCC11CCN(C1)C(=O)c1ccn(C)n1
# 3         A00076817         Cn1cc(cn1)N1CCC2(CCN(C2)C(=O)c2ccncc2)C1=O
# 4         A00079315              CC(C)CN1CC2CN(CC2C1)S(=O)(=O)c1ccccc1
# ...             ...                                                ...
# 47218     U21835532                                                NaN
# 47219     U32963902                                                NaN
# 47220     U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 47221     U84341231                                                NaN
# 47222           NaN                                                NaN
#
#                   compound_name  pubchem_cid kegg_id
# 0                           NaN          NaN     NaN
# 1                  mls000090966          NaN     NaN
# 2                           NaN          NaN     NaN
# 3                           NaN          NaN     NaN
# 4                           NaN          NaN     NaN
# ...                         ...          ...     ...
# 47218  tempol (4-hydroxy-tempo)          NaN     NaN
# 47219           zinc pyrithione          NaN     NaN
# 47220          amikacin hydrate   16218899.0     NaN
# 47221                       NaN          NaN     NaN
# 47222                       NaN          NaN     NaN
#
# [47223 rows x 5 columns]

# %%
df = pd.DataFrame(raw_data_2019_compound_annotation.compound_stem)
no_duplicate_2019=pd.DataFrame.drop_duplicates(df)
no_duplicate_2019
# Out:
#       compound_stem
# 0         A00052363
# 1         A00055639
# 2         A00064324
# 3         A00076817
# 4         A00079315
# ...             ...
# 47218     U21835532
# 47219     U32963902
# 47220     U78772829
# 47221     U84341231
# 47222           NaN
#
# [47223 rows x 1 columns]

# %% [markdown]
# # Chemical Genomics of Tuberculosis - 3226 compounds x 4 concentrations x 100 strains
#
# 2018-08-20
#
# ## Description
#
# Structure and function annotation of compounds used in screen.
#
# ## Data structure
#
# One row per compound structure.
#
# ## Columns
#
# **compound_stem**: Compound structure identifier.  Matches middle field of BRD-XXXXXXXXX-XXX-XX-X compound identifiers.
#
# **SMILES**: SMILES string for compound structure.
#
# **compound_name**: Name of compound.
#
# **pubchem_cid**: PubChem Compound ID.
#
# **kegg_id**: KEGGDrug ID.
#
# **classifier_target**: Target of compound, if known.
#
# **similar_to**: Compound target family to which this compound is trivially similar in structure and chemical genetic interaction profile.
#
# ## Questions?
#
# Email hung {at} broadinstitute.org.

# %%
raw_data_2018_compound_annotation = pd.read_csv('2018-08-20_compound-annotation.csv')
raw_data_2018_compound_annotation
# Out:
#      compound_stem                                             SMILES  \
# 0        K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1        U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 2        A56169713  CNC(C)[C@@H]1CC[C@@H](N)[C@@H](OC2[C@@H](N)C[C...
# 3        A24252652  CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H...
# 4        M53946149  CCN[C@@H]1C[C@H](N)[C@@H](O[C@H]2OC(CN)=CC[C@H...
# ...            ...                                                ...
# 3140     K53414658  COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c...
# 3141     K28428262  C[C@@H](O)COc1cn2ncnc(Oc3ccc4[nH]c(C)cc4c3F)c2c1C
# 3142     K70592963                      O=C1C(C(=O)c2ccccc12)c1ccccc1
# 3143     K86307448                              O=c1[nH]cnc2[nH]ncc12
# 3144     K48367671            CC(C)COc1ccc(cc1C#N)-c1nc(C)c(s1)C(O)=O
#
#                         compound_name  pubchem_cid kegg_kid  \
# 0                            amikacin      37768.0   D00865
# 1                    amikacin hydrate   16218899.0      NaN
# 2     gentamycin sulfate (gentacycol)   53245641.0      NaN
# 3                        hygromycin b   56928061.0      NaN
# 4                  netilmicin sulfate      62115.0      NaN
# ...                               ...          ...      ...
# 3140                        Tivozanib    9911830.0   D09683
# 3141                         Brivanib   11234052.0   D08878
# 3142                      phenindione       4760.0   D08354
# 3143                      allopurinol       2094.0   D00224
# 3144                       Febuxostat     134018.0   D01206
#
#                    classifier_target similar_to
# 0     30S ribosome 16S rRNA decoding        NaN
# 1     30S ribosome 16S rRNA decoding        NaN
# 2     30S ribosome 16S rRNA decoding        NaN
# 3     30S ribosome 16S rRNA decoding        NaN
# 4     30S ribosome 16S rRNA decoding        NaN
# ...                              ...        ...
# 3140                             NaN        NaN
# 3141                             NaN        NaN
# 3142                             NaN        NaN
# 3143                             NaN        NaN
# 3144                             NaN        NaN
#
# [3145 rows x 7 columns]

# %%
reduced_data_2018_compound_annotation=raw_data_2018_compound_annotation.loc[:, ['compound_stem', 'SMILES', 'compound_name','pubchem_cid','kegg_kid']]
reduced_data_2018_compound_annotation
# Out:
#      compound_stem                                             SMILES  \
# 0        K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1        U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 2        A56169713  CNC(C)[C@@H]1CC[C@@H](N)[C@@H](OC2[C@@H](N)C[C...
# 3        A24252652  CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H...
# 4        M53946149  CCN[C@@H]1C[C@H](N)[C@@H](O[C@H]2OC(CN)=CC[C@H...
# ...            ...                                                ...
# 3140     K53414658  COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c...
# 3141     K28428262  C[C@@H](O)COc1cn2ncnc(Oc3ccc4[nH]c(C)cc4c3F)c2c1C
# 3142     K70592963                      O=C1C(C(=O)c2ccccc12)c1ccccc1
# 3143     K86307448                              O=c1[nH]cnc2[nH]ncc12
# 3144     K48367671            CC(C)COc1ccc(cc1C#N)-c1nc(C)c(s1)C(O)=O
#
#                         compound_name  pubchem_cid kegg_kid
# 0                            amikacin      37768.0   D00865
# 1                    amikacin hydrate   16218899.0      NaN
# 2     gentamycin sulfate (gentacycol)   53245641.0      NaN
# 3                        hygromycin b   56928061.0      NaN
# 4                  netilmicin sulfate      62115.0      NaN
# ...                               ...          ...      ...
# 3140                        Tivozanib    9911830.0   D09683
# 3141                         Brivanib   11234052.0   D08878
# 3142                      phenindione       4760.0   D08354
# 3143                      allopurinol       2094.0   D00224
# 3144                       Febuxostat     134018.0   D01206
#
# [3145 rows x 5 columns]

# %%
all_compounds = pd.concat([reduced_data_2018_compound_annotation, raw_data_2019_compound_annotation])
all_compounds
# Out:
#       compound_stem                                             SMILES  \
# 0         K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1         U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 2         A56169713  CNC(C)[C@@H]1CC[C@@H](N)[C@@H](OC2[C@@H](N)C[C...
# 3         A24252652  CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H...
# 4         M53946149  CCN[C@@H]1C[C@H](N)[C@@H](O[C@H]2OC(CN)=CC[C@H...
# ...             ...                                                ...
# 47218     U21835532                                                NaN
# 47219     U32963902                                                NaN
# 47220     U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 47221     U84341231                                                NaN
# 47222           NaN                                                NaN
#
#                          compound_name  pubchem_cid kegg_kid kegg_id
# 0                             amikacin      37768.0   D00865     NaN
# 1                     amikacin hydrate   16218899.0      NaN     NaN
# 2      gentamycin sulfate (gentacycol)   53245641.0      NaN     NaN
# 3                         hygromycin b   56928061.0      NaN     NaN
# 4                   netilmicin sulfate      62115.0      NaN     NaN
# ...                                ...          ...      ...     ...
# 47218         tempol (4-hydroxy-tempo)          NaN      NaN     NaN
# 47219                  zinc pyrithione          NaN      NaN     NaN
# 47220                 amikacin hydrate   16218899.0      NaN     NaN
# 47221                              NaN          NaN      NaN     NaN
# 47222                              NaN          NaN      NaN     NaN
#
# [50368 rows x 6 columns]

# %%
all_compounds.loc[all_compounds.compound_stem == 'K88043978']
# Out:
#       compound_stem                                             SMILES  \
# 0         K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 42595     K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
#
#       compound_name  pubchem_cid kegg_kid kegg_id
# 0          amikacin      37768.0   D00865     NaN
# 42595      amikacin      37768.0      NaN  D00865

# %%
no_duplicates_all_compounds=all_compounds.drop_duplicates()
no_duplicates_all_compounds
# Out:
#       compound_stem                                             SMILES  \
# 0         K88043978  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1         U78772829  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
# 2         A56169713  CNC(C)[C@@H]1CC[C@@H](N)[C@@H](OC2[C@@H](N)C[C...
# 3         A24252652  CN[C@H]1C[C@@H](N)[C@H](O)[C@@H](O[C@@H]2O[C@H...
# 4         M53946149  CCN[C@@H]1C[C@H](N)[C@@H](O[C@H]2OC(CN)=CC[C@H...
# ...             ...                                                ...
# 47214     M97497096  C\C=C\c1ccc2[C@H]3N[C@H]([C@H](CO)[C@H]3Cn2c1=...
# 47215     M99992213  CCN1[C@@H](C(=O)Nc2ccccc2)[C@H](CO)[C@H]2Cn3c(...
# 47217     U20739209                                                NaN
# 47221     U84341231                                                NaN
# 47222           NaN                                                NaN
#
#                          compound_name  pubchem_cid kegg_kid kegg_id
# 0                             amikacin      37768.0   D00865     NaN
# 1                     amikacin hydrate   16218899.0      NaN     NaN
# 2      gentamycin sulfate (gentacycol)   53245641.0      NaN     NaN
# 3                         hygromycin b   56928061.0      NaN     NaN
# 4                   netilmicin sulfate      62115.0      NaN     NaN
# ...                                ...          ...      ...     ...
# 47214           brd-m97497096-001-01-8          NaN      NaN     NaN
# 47215           brd-m99992213-001-01-4          NaN      NaN     NaN
# 47217                              NaN          NaN      NaN     NaN
# 47221                              NaN          NaN      NaN     NaN
# 47222                              NaN          NaN      NaN     NaN
#
# [49823 rows x 6 columns]

# %%
no_duplicates_all_compounds.to_excel('all_compounds_annotation_from_paper.xlsx')
