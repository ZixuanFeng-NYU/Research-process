# %%
import pandas as pd

# %%
info=pd.read_csv('csv/combined_annotation_and_value.csv')
info.head()
# Out:
# /Users/zixuanfeng/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   compound_stem                                             SMILES  \
# 0     A00113255  CC1(C)C[C@H](C2CC[C@]3(C)C(=CC[C@@H]4[C@@]5(C)...
# 1     A00113255  CC1(C)C[C@H](C2CC[C@]3(C)C(=CC[C@@H]4[C@@]5(C)...
# 2     A00113255  CC1(C)C[C@H](C2CC[C@]3(C)C(=CC[C@@H]4[C@@]5(C)...
# 3     A00113255  CC1(C)C[C@H](C2CC[C@]3(C)C(=CC[C@@H]4[C@@]5(C)...
# 4     A00113255  CC1(C)C[C@H](C2CC[C@]3(C)C(=CC[C@@H]4[C@@]5(C)...
#
#                                        compound_name  pubchem_cid kegg_kid  \
# 0  Oleanolic Acid, Caryophyllin, Astrantiagenin C...   49867939.0      NaN
# 1  Oleanolic Acid, Caryophyllin, Astrantiagenin C...   49867939.0      NaN
# ...

# %%
info[~pd.isnull(info['classifier_target'])].to_excel('excel/combined_info_for_known_target_inhibitor_pair_from_paper.xlsx')
